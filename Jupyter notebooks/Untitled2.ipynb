# %%
arr=[1,2,3,4,5,5,4,5,4,3]

revised_arr=set(arr)
print(revised_arr)
# Out:
# {1, 2, 3, 4, 5}

# %%
arr=[]
n=int(input("enter no"))
for i in range(n):
    ele=input("enter nos")
    arr.append(ele)
new_arr=sorted(set(arr))
print(new_arr)
# Out:
# enter no 5
# enter nos 1
# enter nos 11
# enter nos 6
# enter nos 21
# enter nos 11
# ['1', '11', '21', '6']
