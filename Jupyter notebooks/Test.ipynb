# %%
print("hi")
# Out:
# hi

# %%
cube=lambda y: y*y*y
print("cube:",cube(5))
# Out:
# cube: 125

# %%
# Define a recursive function to add two numbers
def add_numbers_recursive(x, y):
    if y == 0:
        return x
    else:
        return add_numbers_recursive(x + 1, y - 1)

# Take input from the user
num1 = 1
num2 = 2

# Call the recursive function to add the two numbers
result = add_numbers_recursive(num1, num2)

# Print the result
print("The sum of", num1, "and", num2, "is", result)
# Out:
# The sum of 1 and 2 is 3

# %%
def add_no(x,y):
    if y==0:
        return x
    else:
        return add_no ( x + 1, y - 1)
a=12
b=24

res = add_no(a,b)

print(a,b,res)
# Out:
# 12 24 36

# %%
a=5
b=3
res = a&b
print(res)
# Out:
# 1

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

combined_list = list1 + list2
print(combined_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr=[1,1,2,6,4,9]
print(arr)
arr=list(set(arr))
print(arr)
# Out:
# [1, 1, 2, 6, 4, 9]
# [1, 2, 4, 6, 9]

# %%
class Solution:
    def runningSum(self, nums: List[int]) -> List[int]:
        add=0
        l=[]
        for i in nums:
            add+=i
            l.append(add)
            return l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8780/1581306516.py in <module>
# ----> 1 class Solution:
#       2     def runningSum(self, nums: List[int]) -> List[int]:
#       3         add=0
#       4         l=[]
#       5         for i in nums:
#
# /tmp/ipykernel_8780/1581306516.py in Solution()
#       1 class Solution:
# ----> 2     def runningSum(self, nums: List[int]) -> List[int]:
#       3         add=0
#       4         l=[]
#       5         for i in nums:
#
# NameError: name 'List' is not defined

# %%
# Example usage
solution = Solution()
nums = [1, 2, 3, 4]
result = solution.runningSum(nums)
print(result)  # Output: [1, 3, 6, 10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8780/1746502356.py in <module>
#       1 # Example usage
# ----> 2 solution = Solution()
#       3 nums = [1, 2, 3, 4]
#       4 result = solution.runningSum(nums)
#       5 print(result)  # Output: [1, 3, 6, 10]
#
# NameError: name 'Solution' is not defined

# %%
from typing import List

class Solution:
    def runningSum(self, nums: List[int]) -> List[int]:
        add = 0
        l = []
        for i in nums:
            add += i 
            print(add)# Add the current number to the running total
            l.append(add)  # Append the running total to the list
        return l  # Return the list after the loop completes

# %%
# Example usage
solution = Solution()
nums = [1, 2, 3, 4]
result = solution.runningSum(nums)
print(result)  # Output: [1, 3, 6, 10]
# Out:
# 1
# 3
# 6
# 10
# [1, 3, 6, 10]

# %%
def sum_natural_numbers(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

# Example usage
n = 5
result = sum_natural_numbers(n)
print(f"The sum of the first {n} natural numbers is: {result}")  # Output: 15
# Out:
# The sum of the first 5 natural numbers is: 15

# %%
def summ(n):
    total = 0
    for i in range( 0, n + 1):
        total= total + i
    return total



result = summ(5)
print(result)
# Out:
# 15

# %%
hashmap={}

hashmap['apple']=3
hashmap['orange']=5

print(hashmap['apple']+hashmap['orange'])
# Out:
# 8

# %%
print('orange'in hashmap)
# Out:
# True

# %%
#test
for key, value in hashmap.items():
    print(f'{key}: {value}')
# Out:
# apple: 3
# orange: 5

# %%
name = 'Alice'
age = 30

# Using % operator
message = 'Hello, my name is %s and I am %d years old.' % (name, age)
print(message)
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
name = 'Alice'
age = 30

# Using str.format() method
message = f"Hello, my name is {name} and I am {age} years old."
print(message)
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
name = 'Alice'
age = 30

# Using f-string
message = f'Hello, my name is {name} and I am {age} years old.'
print(message)

# %%
words=["apple","banana","orange"]

for i, fruits in enumerate(words):
    print(f"index:{i},fruits{fruits}")
# Out:
# index:0,fruitsapple
# index:1,fruitsbanana
# index:2,fruitsorange

# %%
x=["abc","cde","fgh"]

for i in range(len(x)):
    print (f"index:{i+1},name:{x[i]}")
# Out:
# index:1,name:abc
# index:2,name:cde
# index:3,name:fgh

# %%
x=["abc","cde","fgh"]

for i, name in enumerate(x):
    print(f"name:{name},index:{i}")
# Out:
# name:abc,index:0
# name:cde,index:1
# name:fgh,index:2

# %%
string="ajay";

print(string)

gg=list(string)

print (gg)
gg.reverse()
print(gg)
# Out:
# ajay
# ['a', 'j', 'a', 'y']
# ['y', 'a', 'j', 'a']

# %%
list =["abc","def","ghi"]
for i, name in enumerate(list):
    print(f"index:{i}name:{name}")
# Out:
# index:0name:abc
# index:1name:def
# index:2name:ghi
